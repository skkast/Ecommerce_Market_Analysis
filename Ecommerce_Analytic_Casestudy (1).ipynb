# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Cust_data=pd.read_csv(r"D:\DATA SCIENCE\python\Python Case study\Python Foundation End to End Case Study E-Commerce Analytics Project (2)\5. Python Foundation End to End Case Study_E-Commerce Analytics Project\CUSTOMERS.csv")

# %%
Cust_data
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix customer_city  customer_state
# ...

# %%
Cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
GeoLocat_data=pd.read_csv(r"D:\DATA SCIENCE\python\Python Case study\Python Foundation End to End Case Study E-Commerce Analytics Project (2)\5. Python Foundation End to End Case Study_E-Commerce Analytics Project\GEO_LOCATION.csv")

# %%
GeoLocat_data
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                             1037       -23.545621       -46.639292
# 1                             1046       -23.546081       -46.644820
# 2                             1041       -23.544392       -46.639499
# 3                             1035       -23.541578       -46.641607
# 4                             1012       -23.547762       -46.635361
# ...                            ...              ...              ...
# 19010                        99955       -28.107588       -52.144019
# 19011                        99970       -28.345143       -51.876926
# 19012                        99910       -27.863500       -52.084760
# 19013                        99920       -27.858716       -52.300403
# 19014                        99952       -28.160371       -51.936922
#
#       geolocation_city geolocation_state
# 0         Akkarampalle    Andhra Pradesh
# 1         Akkarampalle    Andhra Pradesh
# ...

# %%
GeoLocat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19015 entries, 0 to 19014
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  19015 non-null  int64
#  1   geolocation_lat              19015 non-null  float64
#  2   geolocation_lng              19015 non-null  float64
#  3   geolocation_city             19015 non-null  object
#  4   geolocation_state            19015 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 742.9+ KB

# %%
OrderItem_data=pd.read_csv(r"D:\DATA SCIENCE\python\Python Case study\Python Foundation End to End Case Study E-Commerce Analytics Project (2)\5. Python Foundation End to End Case Study_E-Commerce Analytics Project\ORDER_ITEMS.csv")

# %%
OrderItem_data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
OrderItem_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
OrderItem_data['shipping_limit_date']=pd.to_datetime(OrderItem_data['shipping_limit_date'],errors='coerce', dayfirst=False)

# %%
OrderItem_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
OrderItem_data['shipping_limit_date']
# Out:
# 0        2017-09-19 09:45:00
# 1        2017-05-03 11:05:00
# 2        2018-01-18 14:48:00
# 3        2018-08-15 10:10:00
# 4        2017-02-13 13:57:00
#                  ...
# 112645   2018-05-02 04:11:00
# 112646   2018-07-20 04:31:00
# 112647   2017-10-30 17:14:00
# 112648   2017-08-21 00:04:00
# 112649   2018-06-12 17:10:00
# Name: shipping_limit_date, Length: 112650, dtype: datetime64[ns]

# %%
OrderPayment_data=pd.read_csv(r"D:\DATA SCIENCE\python\Python Case study\Python Foundation End to End Case Study E-Commerce Analytics Project (2)\5. Python Foundation End to End Case Study_E-Commerce Analytics Project\ORDER_PAYMENTS.csv")

# %%
OrderPayment_data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1          UPI
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1          UPI
#
#         payment_installments  payment_value
# ...

# %%
OrderPayment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
OrderRating_data=pd.read_csv(r"D:\DATA SCIENCE\python\Python Case study\Python Foundation End to End Case Study E-Commerce Analytics Project (2)\5. Python Foundation End to End Case Study_E-Commerce Analytics Project\ORDER_REVIEW_RATINGS.csv")

# %%
OrderRating_data
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_creation_date review_answer_timestamp
# ...

# %%
OrderRating_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_creation_date     100000 non-null  object
#  4   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
OrderRating_data['review_creation_date']=pd.to_datetime(OrderRating_data.review_creation_date,errors='coerce', dayfirst=False)
OrderRating_data['review_answer_timestamp']=pd.to_datetime(OrderRating_data['review_answer_timestamp'],errors='coerce', dayfirst=False)

# %%
OrderRating_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_creation_date     100000 non-null  datetime64[ns]
#  4   review_answer_timestamp  100000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 3.8+ MB

# %%
Order_data=pd.read_csv(r"D:\DATA SCIENCE\python\Python Case study\Python Foundation End to End Case Study E-Commerce Analytics Project (2)\5. Python Foundation End to End Case Study_E-Commerce Analytics Project\ORDERS.csv")

# %%
Order_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
Order_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
Order_data['order_purchase_timestamp']=pd.to_datetime(Order_data['order_purchase_timestamp'],errors='coerce', dayfirst=False)

# %%
Order_data['order_approved_at']=pd.to_datetime(Order_data['order_approved_at'],errors='coerce', dayfirst=False)

# %%
Order_data['order_delivered_carrier_date']=pd.to_datetime(Order_data['order_delivered_carrier_date'],errors='coerce', dayfirst=False)

# %%
Order_data['order_delivered_customer_date']=pd.to_datetime(Order_data['order_delivered_customer_date'],errors='coerce', dayfirst=False)

# %%
Order_data['order_estimated_delivery_date']=pd.to_datetime(Order_data['order_estimated_delivery_date'],errors='coerce', dayfirst=False)

# %%
Order_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
Order_data.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
product_data=pd.read_csv(r"D:\DATA SCIENCE\python\Python Case study\Python Foundation End to End Case Study E-Commerce Analytics Project (2)\5. Python Foundation End to End Case Study_E-Commerce Analytics Project\PRODUCTS.csv")

# %%
product_data
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  Perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        Art
# 2      96bd76ec8810374ed1b65e291975717f             Sports_Leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       Baby
# 4      9dc1a7de274444849c219cff195d0b71                 Housewares
# ...                                 ...                        ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            Furniture_Decor
# 32947  bf4538d88321d0fd4412a93c974510e6  Construction_Tools_Lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             Bed_Bath_Table
# 32949  83808703fc0706a22e264b9d75f04a2e      Computers_Accessories
# 32950  106392145fca363410d287a815be6de4             Bed_Bath_Table
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# ...

# %%
product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32328 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_data.isna().sum()
# Out:
# product_id                      0
# product_category_name         623
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
seller_data=pd.read_csv(r"D:\DATA SCIENCE\python\Python Case study\Python Foundation End to End Case Study E-Commerce Analytics Project (2)\5. Python Foundation End to End Case Study_E-Commerce Analytics Project\SELLERS.csv")

# %%
seller_data
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13023
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#           seller_city    seller_state
# 0               Alwal  Andhra Pradesh
# 1               Alwal  Andhra Pradesh
# 2           Badepalle  Andhra Pradesh
# 3        Akkarampalle  Andhra Pradesh
# ...

# %% [raw]
# seller_data.info()

# %%
seller_data.isna().sum()
# Out:
# seller_id                  0
# seller_zip_code_prefix     0
# seller_city               57
# seller_state              57
# dtype: int64

# %% [markdown]
# # 1. Perform Detailed exploratory analysis

# %% [markdown]
# ##  a.] Define & calculate high level metrics like (Total Revenue, Total quantity, Totalproducts, Total categories, Total sellers, Total locations, Total channels, Total payment methods etc…)

# %% [markdown]
# ## Total Revenue

# %%
OrderPayment_data.payment_value.sum()
# Out:
# 16008872.12

# %% [markdown]
# ## TotalProduct

# %%
product_data.product_id.nunique()
# Out:
# 32951

# %% [markdown]
#  ## Total categories

# %%
product_data.product_category_name.nunique()
# Out:
# 71

# %% [markdown]
# ## Total sellers

# %%
seller_data.seller_id.nunique()
# Out:
# 3095

# %% [markdown]
# ## Total payment methods

# %%
OrderPayment_data.payment_type.nunique()
# Out:
# 5

# %% [markdown]
# ## Total Customer Location

# %%
Cust_data.customer_city.nunique()
# Out:
# 4119

# %%
Cust_data.customer_state.nunique()
# Out:
# 20

# %% [markdown]
# ## Total seller Location

# %%
seller_data.seller_city.nunique()
# Out:
# 534

# %%
seller_data.seller_state.nunique()
# Out:
# 19

# %% [markdown]
# ### b.] Understanding how many new customers acquired every month

# %%
Order_data['Purchase_month'] = Order_data.order_purchase_timestamp.dt.to_period('M')

# %%
Order_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
# Step 1: Get the first purchase month for each customer
first_purchase = Order_data.groupby('customer_id')['Purchase_month'].min().reset_index()

# %%
# Step 2: Count how many customers had their first purchase in each month
new_customers_per_month=first_purchase['Purchase_month'].value_counts().sort_index()

# %%
new_customers_per_month
# Out:
# Purchase_month
# 2016-09       4
# 2016-10     324
# 2016-12       1
# 2017-01     800
# 2017-02    1780
# 2017-03    2682
# 2017-04    2404
# 2017-05    3700
# 2017-06    3245
# 2017-07    4026
# 2017-08    4331
# 2017-09    4285
# 2017-10    4631
# 2017-11    7544
# 2017-12    5673
# 2018-01    7269
# 2018-02    6728
# 2018-03    7211
# 2018-04    6939
# 2018-05    6873
# 2018-06    6167
# 2018-07    6292
# 2018-08    6512
# 2018-09      16
# 2018-10       4
# Freq: M, Name: count, dtype: int64

# %% [markdown]
# ### c. Understand the retention of customers on month on month basis

# %%
Order_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
# Get list of customers per month
customers_by_month = Order_data.groupby('Purchase_month')['customer_id'].unique()

# Calculate how many customers were retained each month
retention_counts = []

months = sorted(customers_by_month.index)

for i in range(len(months) - 1):
    current_month = months[i]
    next_month = months[i + 1]
    
    current_customers = set(customers_by_month[current_month])
    next_customers = set(customers_by_month[next_month])
    
    retained_customers = current_customers & next_customers  # intersection
    
    retention_counts.append({
        'Month': str(next_month),
        'Retained_Customers': len(retained_customers)
    })

# Convert to DataFrame
retention_df = pd.DataFrame(retention_counts)
print(retention_df)
# Out:
#       Month  Retained_Customers
# 0   2016-10                   0
# 1   2016-12                   0
# 2   2017-01                   0
# 3   2017-02                   0
# 4   2017-03                   0
# 5   2017-04                   0
# 6   2017-05                   0
# 7   2017-06                   0
# 8   2017-07                   0
# 9   2017-08                   0
# 10  2017-09                   0
# 11  2017-10                   0
# 12  2017-11                   0
# 13  2017-12                   0
# 14  2018-01                   0
# 15  2018-02                   0
# 16  2018-03                   0
# 17  2018-04                   0
# 18  2018-05                   0
# 19  2018-06                   0
# 20  2018-07                   0
# 21  2018-08                   0
# 22  2018-09                   0
# 23  2018-10                   0

# %% [markdown]
# ### d. How the revenues from existing/new customers on month on month basis

# %%
Order_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
Order_data['First_Purchase_month'] = Order_data.groupby('customer_id')['Purchase_month'].transform('min')

# %%
# Step 1: Classify customer type based on month
Order_data['Customer_Type'] = np.where(
    Order_data['Purchase_month'] == Order_data['First_Purchase_month'],
    'New',
    'Existing'
)

# %%
Payment_merge=pd.merge(left=OrderPayment_data,right=Order_data,how='inner',on='order_id')

# %%
Payment_merge.groupby(['Purchase_month','Customer_Type'])['payment_value'].sum().unstack().fillna(0)
# Out:
# Customer_Type          New
# Purchase_month
# 2016-09             252.24
# 2016-10           59090.48
# 2016-12              19.62
# 2017-01          138488.04
# 2017-02          291908.01
# 2017-03          449863.60
# 2017-04          417788.03
# 2017-05          592918.82
# 2017-06          511276.38
# 2017-07          592382.92
# 2017-08          674396.32
# 2017-09          727762.45
# 2017-10          779677.88
# 2017-11         1194882.80
# 2017-12          878401.48
# 2018-01         1115004.18
# 2018-02          992463.34
# 2018-03         1159652.12
# 2018-04         1160785.48
# 2018-05         1153982.15
# 2018-06         1023880.50
# 2018-07         1066540.75
# 2018-08         1022425.32
# 2018-09            4439.54
# 2018-10             589.67

# %% [markdown]
# ### e.] Understand the trends/seasonality of sales, quantity by category, location, month,week, day, time, channel, payment method etc…

# %% [markdown]
# ### Sales by Category

# %%
Payment_tab=pd.merge(left=OrderItem_data,right=OrderPayment_data,how='inner',on='order_id')

# %%
product_merge=pd.merge(left=Payment_tab,right=product_data,how='inner',on='product_id')

# %%
product_merge.groupby('product_category_name')['payment_value'].sum().reset_index(name='revenue').sort_values(by='revenue',ascending=False)
# Out:
#         product_category_name     revenue
# 7              Bed_Bath_Table  1712553.67
# 43              Health_Beauty  1657373.12
# 15      Computers_Accessories  1585330.45
# 39            Furniture_Decor  1430176.39
# 70              Watches_Gifts  1429216.68
# ..                        ...         ...
# 35                    Flowers     2213.01
# 46             Home_Comfort_2     1710.54
# 11          Cds_Dvds_Musicals     1199.43
# 29  Fashion_Childrens_Clothes      785.67
# 61      Security_And_Services      324.51
#
# [71 rows x 2 columns]

# %% [markdown]
# ### Sales by Payment_Method

# %%
product_merge.groupby('payment_type')['payment_value'].sum().reset_index(name='revenue').sort_values(by='revenue',ascending=False)
# Out:
#   payment_type      revenue
# 1  credit_card  15589028.22
# 0          UPI   4059699.60
# 3      voucher    405873.03
# 2   debit_card    253533.86

# %% [markdown]
# ### Sales by location

# %%
Merge_table=pd.merge(left=Order_data,right=Payment_tab,how='inner',on='order_id')

# %%
Cust_merge=pd.merge(left=Merge_table,right=Cust_data,how='inner',on='customer_id')

# %%
Cust_merge.groupby('customer_state')['payment_value'].sum().reset_index(name='revenue').sort_values(by='revenue',ascending=False)
# Out:
#        customer_state      revenue
# 0      Andhra Pradesh  12105033.80
# 5             Gujarat   1607461.11
# 2        Chhattisgarh   1307870.49
# 9           Karnataka    795840.81
# 3               Delhi    731575.44
# 11     Madhya Pradesh    600853.55
# 16         Tamil Nadu    469682.30
# 6             Haryana    456062.24
# 12        Maharashtra    425633.33
# 8     Jammu & Kashmir    334496.74
# 10             Kerala    310345.98
# 1   Arunachal Pradesh    229882.49
# 17      Uttar Pradesh    216788.50
# 15          Rajasthan    173710.69
# 7    Himachal Pradesh    155880.39
# 14             Punjab    132653.01
# 13             Orissa    129221.61
# 19        West Bengal    105403.03
# 18        Uttaranchal     18749.37
# 4                 Goa       989.83

# %% [markdown]
# ### Sales by Month

# %%
Merge_table['Order_PurchaseMonth']=Merge_table.order_purchase_timestamp.dt.month

# %%
Merge_table.groupby('Order_PurchaseMonth')['payment_value'].sum().reset_index(name='revenue').sort_values(by='revenue',ascending=False)
# Out:
#     Order_PurchaseMonth     revenue
# 4                     5  2231479.39
# 7                     8  2099749.62
# 6                     7  2088998.42
# 2                     3  2002561.61
# 3                     4  2002477.05
# 5                     6  1898348.08
# 1                     2  1650183.59
# 0                     1  1596145.06
# 10                   11  1583869.01
# 9                    10  1095083.85
# 11                   12  1042875.48
# 8                     9  1016363.55

# %% [markdown]
# ### Sales by Day

# %%
Merge_table['Order_PurchaseDay']=Merge_table.order_purchase_timestamp.dt.day_name()

# %%
Merge_table.groupby('Order_PurchaseDay')['payment_value'].sum().reset_index(name='revenue').sort_values(by='revenue',ascending=False)
# Out:
#   Order_PurchaseDay     revenue
# 1            Monday  3314375.62
# 5           Tuesday  3312323.20
# 6         Wednesday  3157061.03
# 4          Thursday  3095264.32
# 0            Friday  3011159.85
# 3            Sunday  2271548.82
# 2          Saturday  2146401.87

# %% [markdown]
# ### Sales by Time

# %%
Merge_table['Order_PurchaseTime']=Merge_table.order_purchase_timestamp.dt.time

# %%
Merge_table.groupby('Order_PurchaseTime')['payment_value'].sum().reset_index(name='revenue').sort_values(by='revenue',ascending=False)
# Out:
#     Order_PurchaseTime    revenue
# 917           15:24:00  130147.80
# 555           09:22:00   71154.38
# 923           15:30:00   66616.48
# 882           14:49:00   60353.33
# 656           11:03:00   60189.74
# ..                 ...        ...
# 283           04:48:00      44.89
# 285           04:50:00      40.77
# 363           06:10:00      36.39
# 299           05:04:00      31.27
# 230           03:51:00      26.68
#
# [1433 rows x 2 columns]

# %% [markdown]
# ### Sales by week

# %%
Merge_table['week_number'] = Merge_table['order_purchase_timestamp'].dt.isocalendar().week

# %%
Merge_table.groupby('week_number')['payment_value'].sum().reset_index(name='revenue').sort_values(by='revenue',ascending=False)
# Out:
#     week_number    revenue
# 46           47  658518.60
# 31           32  628741.90
# 18           19  623626.86
# 30           31  570970.96
# 19           20  569137.89
# 29           30  534428.61
# 28           29  517292.10
# 32           33  514368.41
# 15           16  495445.22
# 17           18  492082.69
# 16           17  484915.87
# 8             9  481525.65
# 11           12  472117.88
# 9            10  470325.79
# 13           14  469651.56
# 23           24  465962.97
# 22           23  463769.31
# 10           11  449663.63
# 21           22  436306.13
# 4             5  431253.21
# 12           13  427013.18
# 7             8  426434.49
# 14           15  419251.18
# 27           28  416767.18
# 25           26  415658.66
# 24           25  408351.28
# 47           48  401027.73
# 26           27  396680.21
# 5             6  396394.64
# 3             4  387696.29
# 1             2  386256.69
# 20           21  381595.64
# 33           34  378626.87
# ...

# %% [markdown]
# ## f].Popular Products by month, seller, state, category.

# %% [markdown]
# ### Popular Products by category

# %%
product_data.groupby(['product_id', 'product_category_name']).size().reset_index(name='count')
# Out:
#                              product_id     product_category_name  count
# 0      00066f42aeeb9f3007548bb9d3f33c38                 Perfumery      1
# 1      00088930e925c41fd95ebfe695fd2655                      Auto      1
# 2      0009406fd7479715e4bef61dd91f2462            Bed_Bath_Table      1
# 3      000b8f95fcb9e0096488278317764d19                Housewares      1
# 4      000d9be29b5207b54e86aa1b1ac54872             Watches_Gifts      1
# ...                                 ...                       ...    ...
# 32323  fff6177642830a9a94a0f2cba5e476d1                Cool_Stuff      1
# 32324  fff81cc3158d2725c0655ab9ba0f712c             Health_Beauty      1
# 32325  fff9553ac224cec9d15d49f5a263411f  Fashion_Bags_Accessories      1
# 32326  fffdb2d0ec8d6a61f0a0a0db3f25b441     Computers_Accessories      1
# 32327  fffe9eeff12fcbd74a2f2b007dde0c58                      Toys      1
#
# [32328 rows x 3 columns]

# %% [markdown]
# ### popular_products by seller

# %%
OrderItem_data.groupby(['seller_id','product_id']).size().reset_index(name='count')
# Out:
#                               seller_id                        product_id  \
# 0      0015a82c2db000af6aaaf3ae2ecb0532  a2ff5a97bf95719e38ea2e3b4105bce8
# 1      001cca7ae9ae17fb1caed9dfb1094831  08574b074924071f4e201e151b152b4e
# 2      001cca7ae9ae17fb1caed9dfb1094831  0da9ffd92214425d880de3f94e74ce39
# 3      001cca7ae9ae17fb1caed9dfb1094831  21fecd254a3103704126b28478ea7980
# 4      001cca7ae9ae17fb1caed9dfb1094831  4d7fee7877228c1497477ae53d97c214
# ...                                 ...                               ...
# 34443  ffff564a4f9085cd26170f4732393726  cb17b798ba889575385281b7ec2fc22b
# 34444  ffff564a4f9085cd26170f4732393726  dbd024d4182504993ad1e3cd2ee9d9e9
# 34445  ffff564a4f9085cd26170f4732393726  de6517dda8e49774f58c07f80abc8d7a
# 34446  ffff564a4f9085cd26170f4732393726  e20b58fe57d487f33247e6cc1154eb9c
# 34447  ffff564a4f9085cd26170f4732393726  fa2de9e6a52f697fbd74ddbc2c15b16c
#
#        count
# 0          3
# 1        113
# 2         17
# 3          3
# ...

# %% [markdown]
# ### Popular Products by month

# %%
merge_table=pd.merge(left=OrderItem_data,right=Order_data,how='inner',on='order_id')
merge_table
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
merge_table['month'] = merge_table['order_purchase_timestamp'].dt.month
merge_table.groupby(['month','product_id']).size().reset_index(name='count').sort_values(by=['month','count'], ascending=False)
# Out:
#        month                        product_id  count
# 58263     12  422879e10f46682990de24d770e7f83d     51
# 58394     12  4c2394abfbac7ff59ec7a420918562fa     50
# 59686     12  aca2eb7d00ea1a7b8ebd4e68314663af     47
# 58090     12  368c6c730842d78016ad823897a372db     44
# 58501     12  53759a2ecddad2bb87a079a1f1519f73     40
# ...      ...                               ...    ...
# 4634       1  ffccf0ce5eff1a158891296990107d08      1
# 4635       1  ffd246249e3225c13f40b5b91dcaa65a      1
# 4636       1  ffd34459c21034d1da6df9800de0d7a3      1
# 4637       1  ffd4bf4306745865e5692f69bd237893      1
# 4638       1  ffe0fc4e02c3559643ac063fa5cf9d07      1
#
# [60796 rows x 3 columns]

# %% [markdown]
# ### Popular Products by state

# %%
merg_data=pd.merge(left=merge_table,right=Cust_data,how='inner',on='customer_id')

# %%
merg_data.groupby(['product_id','customer_state']).size().reset_index(name='count').sort_values(by=['customer_state','count'], ascending=False)
# Out:
#                              product_id  customer_state  count
# 33065  99a4788cb24856965c36a24e339b6058     West Bengal      6
# 10494  30ac6df06dc59ad72cf2f158fc2d904c     West Bengal      5
# 12243  389d119b48cf3043d311335e499d9c6b     West Bengal      5
# 55131  ffaf0af7eebb57c7f262b51ebb05dfd6     West Bengal      4
# 6147   1ba4e3fe92f16fd5a8942f7b7d804b52     West Bengal      3
# ...                                 ...             ...    ...
# 55196  fff28f91211774864a1000f918ed00cc  Andhra Pradesh      1
# 55197  fff515ea94dbf35d54d256b3e39f0fea  Andhra Pradesh      1
# 55198  fff6177642830a9a94a0f2cba5e476d1  Andhra Pradesh      1
# 55200  fff81cc3158d2725c0655ab9ba0f712c  Andhra Pradesh      1
# 55201  fff9553ac224cec9d15d49f5a263411f  Andhra Pradesh      1
#
# [55205 rows x 3 columns]

# %% [markdown]
# ## g] Popular categories by state, month

# %%
merge_table
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# ### Popular categories by month

# %%
Categ_merge=pd.merge(left=merge_table,right=product_data,how='inner',on='product_id')

# %%
Categ_merge.groupby(['month','product_category_name']).size().reset_index(name='count').sort_values(by=['month','count'], ascending=False)
# Out:
#      month                  product_category_name  count
# 741     12                         Bed_Bath_Table    552
# 791     12                         Sports_Leisure    493
# 774     12                          Health_Beauty    466
# 795     12                                   Toys    445
# 770     12                        Furniture_Decor    390
# ..     ...                                    ...    ...
# 43       1                         Home_Comfort_2      2
# 55       1                         Party_Supplies      2
# 49       1                             La_Cuisine      1
# 58       1                  Security_And_Services      1
# 61       1  Small_Appliances_Home_Oven_And_Coffee      1
#
# [797 rows x 3 columns]

# %% [markdown]
# ### Popular categories by state

# %%
Cust_merge=pd.merge(left=Categ_merge,right=Cust_data,how='inner',on='customer_id')

# %%
Cust_merge.groupby(['customer_state','product_category_name']).size().reset_index(name='count').sort_values(by=['customer_state','count'], ascending=False)
# Out:
#       customer_state      product_category_name  count
# 1056     West Bengal              Health_Beauty     44
# 1073     West Bengal                  Telephony     34
# 1041     West Bengal      Computers_Accessories     33
# 1038     West Bengal             Bed_Bath_Table     32
# 1071     West Bengal             Sports_Leisure     25
# ...              ...                        ...    ...
# 32    Andhra Pradesh              Fashion_Sport     16
# 11    Andhra Pradesh          Cds_Dvds_Musicals     11
# 52    Andhra Pradesh                 La_Cuisine      9
# 29    Andhra Pradesh  Fashion_Childrens_Clothes      6
# 61    Andhra Pradesh      Security_And_Services      1
#
# [1076 rows x 3 columns]

# %% [markdown]
# ## h]. List top 10 most expensive products sorted by price

# %%
  sorted_data=OrderItem_data.sort_values(by='price',ascending=False)

# %%
sorted_data[['product_id','price']].head(10)
# Out:
#                               product_id    price
# 3556    489ae2aa008f021502940f251d4cce7f  6735.00
# 112233  69c590f7ffc7bf8db97190b6cb6ed62e  6729.00
# 107841  1bdf5e6731585cf01aa8169c7028d6ad  6499.00
# 74336   a6492cc69376c469ab6f61d8f44de961  4799.00
# 11249   c3ed642d592594bb648ff4a04cee2747  4690.00
# 62086   259037a6a41845e455183f89c5035f18  4590.00
# 29193   a1beef8f3992dbd4cd8726796aa69c53  4399.87
# 45843   6cdf8fc1d741c76586d8b6b15e9eef30  4099.99
# 78310   dd113cb02b2af9c8e5787e8f1f0722f6  4059.00
# 59137   6902c1962dd19d540807d0ab8fade5c6  3999.90

# %% [markdown]
# seller_data

# %% [markdown]
# ## 2. Performing Customers/sellers Segmentation
# ## a. Divide the customers into groups based on the revenue generated
# ## b. Divide the sellers into groups based on the revenue generated

# %% [markdown]
# ### a. Divide the customers into groups based on the revenue generated

# %%
OrderPayment_data['payment_value'] = pd.to_numeric(OrderPayment_data['payment_value'], errors='coerce')

# %%
OrderPayment_data['Revenue_Group'] =pd.cut(OrderPayment_data['payment_value'], bins=3, labels=['Low Revenue', 'Medium Revenue', 'High Revenue'])

# %%
OrderPayment_data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1          UPI
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1          UPI
#
#         payment_installments  payment_value Revenue_Group
# ...

# %%
OrderNew_merge=pd.merge(left=Order_data,right=OrderPayment_data,how='inner',on='order_id')

# %%
OrderNew_merge.groupby('Revenue_Group')['customer_id'].count()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13656\2425398110.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   OrderNew_merge.groupby('Revenue_Group')['customer_id'].count()
# Revenue_Group
# Low Revenue       103876
# Medium Revenue         9
# High Revenue           1
# Name: customer_id, dtype: int64

# %% [markdown]
#  ### b. Divide the sellers into groups based on the revenue generated

# %%
OrderItem_data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
Order_merge=pd.merge(left=OrderItem_data,right=OrderNew_merge,how='inner',on='order_id')

# %%
Order_merge
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 117596  fffc94f6ce00a00581880bf54a75a037              1
# 117597  fffcd46ef2263f404302a634eb57f7eb              1
# 117598  fffce4705a9662cd70adb13d4a31832d              1
# 117599  fffe18544ffabc95dfada21779c9644f              1
# 117600  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
Order_merge.groupby('Revenue_Group')['seller_id'].count()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13656\2102243359.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Order_merge.groupby('Revenue_Group')['seller_id'].count()
# Revenue_Group
# Low Revenue       117575
# Medium Revenue        18
# High Revenue           8
# Name: seller_id, dtype: int64

# %% [markdown]
# ## 3. Cross-Selling (Which products are selling together)
# ## Hint: We need to find which of the top 10 combinations of products are selling together in
# ## each transaction. (combination of 2 or 3 buying together)

# %%
order_products = Order_merge.groupby('order_id')['product_id'].apply(list)

# %%
order_products
# Out:
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214    [4244733e06e7ecb4970a6e2683c13e61]
# 00018f77f2f0320c557190d7a144bdd3    [e5f2d52b802189ee658865ca93d83a8f]
# 000229ec398224ef6ca0657da4fc703e    [c777355d18b72b67abbeef9df44fd0fd]
# 00024acbcdf0a6daa1e931b038114c75    [7634da152a4610f1595efa32f14722fc]
# 00042b26cf59d7ce69dfabb4e55b4fd9    [ac6c3623068f30de03045865e4e10089]
#                                                    ...
# fffc94f6ce00a00581880bf54a75a037    [4aa6014eceb682077f9dc4bffebc05b0]
# fffcd46ef2263f404302a634eb57f7eb    [32e07fd915822b0765e448c4dd74c828]
# fffce4705a9662cd70adb13d4a31832d    [72a30483855e2eafc67aee5dc2560482]
# fffe18544ffabc95dfada21779c9644f    [9c422a519119dcad7575db5af1ba540e]
# fffe41c64501cc87c801fd61db3f6244    [350688d9dc1e75ff97be326363655e01]
# Name: product_id, Length: 98665, dtype: object

# %%
from itertools import combinations
from collections import Counter

# Store all combinations
combo_counts = Counter()

# Loop through orders
for products in order_products:
    # Remove duplicates in case product is repeated in same order
    products = list(set(products))
    
    # Generate 2-product and 3-product combos
    for r in [2, 3]:
        combos = combinations(products, r)
        combo_counts.update(combos)

# %%
top_10_combos = combo_counts.most_common(10)

# Display
for combo, count in top_10_combos:
    print(f"{combo} → bought together {count} times")
# Out:
# ('36f60d45225e60c7da4558b070ce4b60', 'e53e557d5a159f5aa2c5e995dfdf244b') → bought together 34 times
# ('35afc973633aaeb6b877ff57b2793310', '99a4788cb24856965c36a24e339b6058') → bought together 29 times
# ('f4f67ccaece962d013a4e1d7dc3a61f7', '4fcb3d9a5f4871e8362dfedbdb02b064') → bought together 17 times
# ('36f60d45225e60c7da4558b070ce4b60', '3f14d740544f37ece8a9e7bc8349797e') → bought together 12 times
# ('389d119b48cf3043d311335e499d9c6b', '422879e10f46682990de24d770e7f83d') → bought together 11 times
# ('389d119b48cf3043d311335e499d9c6b', '53759a2ecddad2bb87a079a1f1519f73') → bought together 9 times
# ('368c6c730842d78016ad823897a372db', '53759a2ecddad2bb87a079a1f1519f73') → bought together 8 times
# ('18486698933fbb64af6c0a255f7dd64c', 'dbb67791e405873b259e4656bf971246') → bought together 7 times
# ('060cb19345d90064d1015407193c233d', '98d61056e0568ba048e5d78038790e77') → bought together 6 times
# ...

# %% [markdown]
# ## 4. Payment Behaviour
# ## a. How customers are paying?
# ## b. Which payment channels are used by most customers??

# %% [markdown]
# ### a. How customers are paying?

# %%
Payment_table=pd.merge(left=OrderPayment_data,right=merge_table,how='inner',on='order_id')

# %%
Payment_table.groupby('payment_type')['customer_id'].count().reset_index(name='count')
# Out:
#   payment_type  count
# 0          UPI  22867
# 1  credit_card  86769
# 2   debit_card   1691
# 3      voucher   6274

# %% [markdown]
# ### b] there is no payment channel so i cann't proceed with this question.

# %% [markdown]
# ## 5. Customer satisfaction towards category & product
# ## a. Which categories (top 10) are maximum rated & minimum rated?
# ## b. Which products (top10) are maximum rated & minimum rated?
# ## c. Average rating by location, seller, product, category, month etc.

# %% [markdown]
# ### a. Which categories (top 10) are maximum rated & minimum rated?

# %%
Merge_table=pd.merge(left=OrderRating_data,right=OrderItem_data,how='inner',on='order_id')

# %%
Rated_merge=pd.merge(left=Merge_table,right=product_data,how='inner',on='product_id')

# %%
Rated_merge.groupby('product_category_name')['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False).head(10)
# Out:
#                     product_category_name  avg_rating
# 11                      Cds_Dvds_Musicals    4.642857
# 29              Fashion_Childrens_Clothes    4.500000
# 8                  Books_General_Interest    4.439421
# 9                          Books_Imported    4.400000
# 22                Costruction_Tools_Tools    4.359223
# 10                        Books_Technical    4.338290
# 53                    Luggage_Accessories    4.309524
# 37                             Food_Drink    4.303571
# 64  Small_Appliances_Home_Oven_And_Coffee    4.302632
# 32                          Fashion_Sport    4.258065

# %%
Rated_merge.groupby('product_category_name')['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False).tail(10)
# Out:
#      product_category_name  avg_rating
# 4                    Audio    3.808219
# 52              La_Cuisine    3.785714
# 27  Fashio_Female_Clothing    3.780000
# 58          Party_Supplies    3.767442
# 34         Fixed_Telephony    3.671698
# 30   Fashion_Male_Clothing    3.621212
# 57        Office_Furniture    3.484421
# 46          Home_Comfort_2    3.366667
# 23     Diapers_And_Hygiene    3.256410
# 61   Security_And_Services    2.500000

# %% [markdown]
# ### b. Which products (top10) are maximum rated & minimum rated?

# %%
Rated_merge
# Out:
#                                review_id                          order_id  \
# 0       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2       80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3       228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4       e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# ...                                  ...                               ...
# 113317  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 113318  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 113319  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 113320  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 113321  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#         review_score review_creation_date review_answer_timestamp  \
# ...

# %%
Rated_merge.groupby('product_id')['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False).head(10)
# Out:
#                              product_id  avg_rating
# 0      00066f42aeeb9f3007548bb9d3f33c38         5.0
# 17330  86743ff92eee3d16b7df59cddd583b8c         5.0
# 17345  868ceb027ab706a4dee42e2220006b85         5.0
# 17343  868969d3a93aeeab7bfcd4fc3d3d65de         5.0
# 17342  868766ed2172644fdd977d6bd395a107         5.0
# 17340  8684bd8f93b4f4038d07188a23811e93         5.0
# 17335  867c96d2bb67aba6500a4c509cf76072         5.0
# 17334  867b820367ec206b38a357f2c12454b7         5.0
# 17333  867901d7e8488fb97f1fb538c09d476e         5.0
# 17325  865bfa00c1dad8f4146d3c2765f051ca         5.0

# %%
Rated_merge.groupby('product_id')['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False).tail(10)
# Out:
#                              product_id  avg_rating
# 30809  ef4f75a1e1266944f1733179e963d4be         1.0
# 28755  defce8530200d29d2c50f4ca66400e06         1.0
# 11912  5bc5205ae68bc0e9997e05fa59b06194         1.0
# 6639   330a8a8d810e84c45bf6fece44e082c8         1.0
# 17124  84a517a0e06ef2a45abff3cab3f0ad0e         1.0
# 13861  6b3e612bee768d758d981f0d7992e07e         1.0
# 3247   1890c01a38d17958d79fe473d451dc9c         1.0
# 19077  94982c575245c1664b51851ec653a79e         1.0
# 23307  b5c114b11d53b6fd85a6a90790f0b479         1.0
# 9831   4bae12e58c9b828e1302a2cad437b80a         1.0

# %% [markdown]
# ### c] Average rating by location, seller, product, category, month etc.

# %%
Rated_merge
# Out:
#                                review_id                          order_id  \
# 0       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2       80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3       228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4       e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# ...                                  ...                               ...
# 113317  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 113318  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 113319  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 113320  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 113321  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#         review_score review_creation_date review_answer_timestamp  \
# ...

# %% [markdown]
# ## Average rating by seller

# %%
Rated_merge.groupby('seller_id')['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False)
# Out:
#                              seller_id  avg_rating
# 2335  c18309219e789960add0b2255ca4b091         5.0
# 2407  c7246702dc991a06d788120dc7544391         5.0
# 2837  eaaa46e98c9e61f6764dd1d7a2ab8b3e         5.0
# 841   466222e777149751370e7e98fb623b0c         5.0
# 2835  ea846a0e7ad98a741783e886d89dfa44         5.0
# ...                                ...         ...
# 2661  dc120d932ddf9d4dfb6fd68beefda622         1.0
# 1438  749e7cdabbaf72f16677859e27874ba5         1.0
# 2645  dadc51ef321949ec9a3ab25cd902e23d         1.0
# 2638  da2782c804606d2a5d8e1760dbb3e7ec         1.0
# 1195  61b893c57e33626afb104d4112b1be76         1.0
#
# [3095 rows x 2 columns]

# %% [markdown]
# ## Average rating by Product

# %%
Rated_merge.groupby('product_id')['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False)
# Out:
#                              product_id  avg_rating
# 0      00066f42aeeb9f3007548bb9d3f33c38         5.0
# 17330  86743ff92eee3d16b7df59cddd583b8c         5.0
# 17345  868ceb027ab706a4dee42e2220006b85         5.0
# 17343  868969d3a93aeeab7bfcd4fc3d3d65de         5.0
# 17342  868766ed2172644fdd977d6bd395a107         5.0
# ...                                 ...         ...
# 13861  6b3e612bee768d758d981f0d7992e07e         1.0
# 3247   1890c01a38d17958d79fe473d451dc9c         1.0
# 19077  94982c575245c1664b51851ec653a79e         1.0
# 23307  b5c114b11d53b6fd85a6a90790f0b479         1.0
# 9831   4bae12e58c9b828e1302a2cad437b80a         1.0
#
# [32951 rows x 2 columns]

# %% [markdown]
# ## Average rating by Category

# %%
Rated_merge.groupby('product_category_name')['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False)
# Out:
#         product_category_name  avg_rating
# 11          Cds_Dvds_Musicals    4.642857
# 29  Fashion_Childrens_Clothes    4.500000
# 8      Books_General_Interest    4.439421
# 9              Books_Imported    4.400000
# 22    Costruction_Tools_Tools    4.359223
# ..                        ...         ...
# 30      Fashion_Male_Clothing    3.621212
# 57           Office_Furniture    3.484421
# 46             Home_Comfort_2    3.366667
# 23        Diapers_And_Hygiene    3.256410
# 61      Security_And_Services    2.500000
#
# [71 rows x 2 columns]

# %% [markdown]
# ## Average rating by Month

# %%
Rated_merge['rating_month']=Rated_merge.review_creation_date.dt.month

# %%
Rated_merge.groupby('rating_month')['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False)
# Out:
#     rating_month  avg_rating
# 6              7    4.189538
# 7              8    4.176293
# 8              9    4.127037
# 5              6    4.104010
# 4              5    4.098516
# 9             10    4.069166
# 10            11    4.035848
# 1              2    3.986097
# 0              1    3.982908
# 3              4    3.865644
# 11            12    3.834181
# 2              3    3.719541

# %% [markdown]
# ## Average rating by location

# %%
Rated_merge
# Out:
#                                review_id                          order_id  \
# 0       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2       80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3       228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4       e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# ...                                  ...                               ...
# 113317  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 113318  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 113319  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 113320  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 113321  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#         review_score review_creation_date review_answer_timestamp  \
# ...

# %%
Seller_merg=pd.merge(left=Rated_merge,right=seller_data,how='inner',on='seller_id')

# %%
Seller_merg.groupby(['seller_state'])['review_score'].mean().reset_index(name='avg_rating').sort_values(by='avg_rating', ascending=False)
# Out:
#          seller_state  avg_rating
# 17        Uttaranchal    4.524590
# 9              Kerala    4.243902
# 12             Orissa    4.229412
# 18        West Bengal    4.185430
# 1   Arunachal Pradesh    4.154248
# 6    Himachal Pradesh    4.149554
# 2        Chhattisgarh    4.111963
# 5             Haryana    4.074761
# 7     Jammu & Kashmir    4.043765
# 14          Rajasthan    4.036458
# 10     Madhya Pradesh    4.034047
# 8           Karnataka    4.033441
# 0      Andhra Pradesh    4.019711
# 11        Maharashtra    4.004762
# 4             Gujarat    3.936198
# 3               Delhi    3.884944
# 15         Tamil Nadu    3.847345
# 16      Uttar Pradesh    3.657143
# 13             Punjab    3.523810
